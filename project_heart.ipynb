# %% [markdown]
# ![image.png](attachment:bef1202c-f542-4210-9f9c-d42fdfc1dbb8.png)

# %% [markdown]
# <div style="
#     margin:20px 0 35px;
#     padding:75px 30px;
#     border-radius:24px;
#     position:relative;
#     overflow:hidden;
#     text-align:center;
#     color:#1F2937;
#     font-family:Arial,sans-serif;
#     background:
#         radial-gradient(circle at 8% 50%,rgba(239,68,68,.20) 0%,transparent 25%),
#         radial-gradient(circle at 92% 25%,rgba(248,113,113,.20) 0%,transparent 28%),
#         radial-gradient(circle at 75% 90%,rgba(220,38,38,.12) 0%,transparent 30%),
#         linear-gradient(135deg,#ffffff 0%,#fff5f5 45%,#fee2e2 100%);
#     box-shadow:0 15px 40px rgba(220,38,38,.16);
# ">
#
# <!-- Heart / Medical decorative elements -->
#
# <div style="
#     position:absolute;
#     left:35px;
#     top:35px;
#     width:90px;
#     height:90px;
#     border-radius:22px;
#     background:rgba(255,255,255,.70);
#     border:2px solid rgba(220,38,38,.15);
#     box-shadow:0 8px 25px rgba(220,38,38,.10);
#     transform:rotate(-8deg);
# ">
#     <div style="
#         font-size:42px;
#         margin-top:20px;
#     ">❤️</div>
# </div>
#
# <div style="
#     position:absolute;
#     right:40px;
#     top:30px;
#     font-size:55px;
#     opacity:.16;
# ">🫀</div>
#
# <div style="
#     position:absolute;
#     right:45px;
#     bottom:30px;
#     width:95px;
#     height:95px;
#     border-radius:50%;
#     background:rgba(255,255,255,.72);
#     border:2px solid rgba(220,38,38,.15);
#     box-shadow:0 8px 25px rgba(220,38,38,.10);
# ">
#     <div style="
#         font-size:45px;
#         margin-top:20px;
#     ">📈</div>
# </div>
#
# <div style="
#     position:absolute;
#     left:20%;
#     bottom:25px;
#     font-size:45px;
#     opacity:.12;
# ">❤️</div>
#
# <div style="
#     position:absolute;
#     right:22%;
#     top:25px;
#     font-size:40px;
#     opacity:.12;
# ">🩺</div>
#
# <!-- Main title -->
#
# <h1 style="
#     position:relative;
#     z-index:2;
#     margin:0;
#     font-size:46px;
#     font-weight:800;
#     letter-spacing:-1px;
#     color:#1F2937;
#     text-shadow:0 3px 15px rgba(220,38,38,.12);
# ">
#     Hello everyone. 👋
# </h1>
#
# <div style="
#     position:relative;
#     z-index:2;
#     width:85px;
#     height:4px;
#     margin:25px auto 0;
#     border-radius:10px;
#     background:linear-gradient(90deg,#DC2626,#F87171,#DC2626);
#     box-shadow:0 0 15px rgba(220,38,38,.35);
# "></div>
#
# </div>

# %% [markdown]
# <div style="
# color:white;
# display:fill;
# border-radius:18px;
# background:linear-gradient(135deg,#450A0A 0%,#991B1B 100%);
# font-family:Verdana,sans-serif;
# letter-spacing:0.3px;
# box-shadow:0 8px 20px rgba(127,29,29,0.25);
# margin:20px 0;
# ">
#
# <div style="
# padding:35px 45px;
# border-left:6px solid #F87171;
# ">
#
# <h2 style="
# color:#FFFFFF;
# margin-top:0;
# margin-bottom:18px;
# font-size:150%;
# ">
# About Dataset
# </h2>
#
# <p style="
# color:#FEE2E2;
# font-size:105%;
# line-height:1.8;
# margin-bottom:12px;
# ">
# This is a heart disease dataset containing 14 columns and 303 rows. The description of each column is provided below in the notebook.
# </p>
#
# <p style="
# color:#FEE2E2;
# font-size:105%;
# line-height:1.8;
# margin-bottom:12px;
# ">
# The dataset contains information about both male and female individuals, including their age, physical characteristics, and other health-related features.
# </p>
#
# </div>
# </div>

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:100px;
#            background:linear-gradient(135deg,#991B1B,#DC2626);
#            font-size:120%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
#
# <p style="padding:50px;
#           color:white;"><strong>Why does the heart never get tired of beating?</strong><br>
# The heart beats continuously throughout our lives, unlike most muscles that need regular rest.
# It contains specialized cells that can generate electrical signals automatically.
# This allows the heart to maintain a regular rhythm without conscious control.
#
# </p>
# </div>

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:100px;
#            background:linear-gradient(135deg,#991B1B,#DC2626);
#            font-size:120%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
#
# <p style="padding:50px;
#           color:white;"><strong>Why is the heart located slightly to the left?</strong><br>
# The heart is positioned near the center of the chest, but its lower part points slightly toward the left.
# This orientation makes the heartbeat more noticeable on the left side of the chest.
# Interestingly, the heart is not actually located entirely on the left side.
#
# </p>
# </div>

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:100px;
#            background:linear-gradient(135deg,#991B1B,#DC2626);
#            font-size:120%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
#
# <p style="padding:50px;
#           color:white;"><strong>How much blood does the heart pump every minute?</strong><br>
# At rest, an average adult heart pumps roughly 5 liters of blood per minute.
# During intense physical activity, this amount can increase dramatically.
# The heart adjusts its output according to the body's oxygen and energy demands.
#
# </p>
# </div>

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:100px;
#            background:linear-gradient(135deg,#991B1B,#DC2626);
#            font-size:120%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
#
# <p style="padding:50px;
#           color:white;"><strong>Why does your heart beat faster when you exercise?</strong><br>
# During exercise, your muscles require more oxygen and nutrients.
# The nervous system signals the heart to beat faster and pump more blood throughout the body.
# This increased blood flow helps deliver oxygen and remove metabolic waste more efficiently.
#
# </p>
# </div>

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:100px;
#            background:linear-gradient(135deg,#991B1B,#DC2626);
#            font-size:120%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
#
# <p style="padding:50px;
#           color:white;">
# In this notebook, I will clean and preprocess the data, analyze it to discover patterns and relationships, and investigate what is happening within the dataset.
# I will also prepare the data for visualization and Exploratory Data Analysis (EDA).
#
# </p>
# </div>

# %% [markdown]
# <div style="
#     margin:25px 0 35px;
#     padding:35px 25px;
#     border-radius:24px;
#     background:
#         radial-gradient(circle at 8% 50%,rgba(239,68,68,.10) 0%,transparent 25%),
#         radial-gradient(circle at 92% 25%,rgba(248,113,113,.12) 0%,transparent 28%),
#         linear-gradient(135deg,#ffffff 0%,#fff8f8 55%,#feecec 100%);
#     box-shadow:0 12px 35px rgba(220,38,38,.12);
#     font-family:Verdana,sans-serif;
# ">
#
# <h2 style="
#     margin:0 0 10px;
#     text-align:center;
#     font-size:32px;
#     font-weight:800;
#     color:#7F1D1D;
#     letter-spacing:.3px;
# ">
#     ❤️ Heart Dataset Features
# </h2>
#
# <p style="
#     margin:0 0 30px;
#     text-align:center;
#     font-size:15px;
#     color:#64748b;
# ">
#     Description of the variables used in the dataset
# </p>
#
# <!-- age -->
#
# <div style="
#     display:flex;
#     align-items:center;
#     margin-bottom:14px;
#     padding:18px 20px;
#     border-radius:14px;
#     background:rgba(255,255,255,.90);
#     border-left:5px solid #EF4444;
#     box-shadow:0 4px 15px rgba(220,38,38,.07);
# ">
#     <div style="
#         width:150px;
#         min-width:150px;
#         font-size:18px;
#         font-weight:800;
#         color:#DC2626;
#     ">age</div>
#     <div style="
#         width:1px;
#         height:40px;
#         background:#F87171;
#         margin-right:20px;
#     "></div>
#     <div style="
#         font-size:15px;
#         line-height:1.7;
#         color:#374151;
#     ">
#         Age of the patient in years.
#     </div>
# </div>
#
# <!-- sex -->
#
# <div style="
#     display:flex;
#     align-items:center;
#     margin-bottom:14px;
#     padding:18px 20px;
#     border-radius:14px;
#     background:rgba(255,255,255,.90);
#     border-left:5px solid #F87171;
#     box-shadow:0 4px 15px rgba(220,38,38,.07);
# ">
#     <div style="
#         width:150px;
#         min-width:150px;
#         font-size:18px;
#         font-weight:800;
#         color:#DC2626;
#     ">sex</div>
#     <div style="
#         width:1px;
#         height:40px;
#         background:#F87171;
#         margin-right:20px;
#     "></div>
#     <div style="
#         font-size:15px;
#         line-height:1.7;
#         color:#374151;
#     ">
#         Gender of the patient (0 = male, 1 = female).
#     </div>
# </div>
#
# <!-- cp -->
#
# <div style="
#     display:flex;
#     align-items:center;
#     margin-bottom:14px;
#     padding:18px 20px;
#     border-radius:14px;
#     background:rgba(255,255,255,.90);
#     border-left:5px solid #F87171;
#     box-shadow:0 4px 15px rgba(220,38,38,.07);
# ">
#     <div style="
#         width:150px;
#         min-width:150px;
#         font-size:18px;
#         font-weight:800;
#         color:#DC2626;
#     ">cp</div>
#     <div style="
#         width:1px;
#         height:40px;
#         background:#F87171;
#         margin-right:20px;
#     "></div>
#     <div style="
#         font-size:15px;
#         line-height:1.7;
#         color:#374151;
#     ">
#         Chest pain type: 0 = Typical angina, 1 = Atypical angina,
#         2 = Non-anginal pain, 3 = Asymptomatic.
#     </div>
# </div>
#
# <!-- trestbps -->
#
# <div style="
#     display:flex;
#     align-items:center;
#     margin-bottom:14px;
#     padding:18px 20px;
#     border-radius:14px;
#     background:rgba(255,255,255,.90);
#     border-left:5px solid #F87171;
#     box-shadow:0 4px 15px rgba(220,38,38,.07);
# ">
#     <div style="
#         width:150px;
#         min-width:150px;
#         font-size:18px;
#         font-weight:800;
#         color:#DC2626;
#     ">trestbps</div>
#     <div style="
#         width:1px;
#         height:40px;
#         background:#F87171;
#         margin-right:20px;
#     "></div>
#     <div style="
#         font-size:15px;
#         line-height:1.7;
#         color:#374151;
#     ">
#         Resting blood pressure measured in mm Hg.
#     </div>
# </div>
#
# <!-- chol -->
#
# <div style="
#     display:flex;
#     align-items:center;
#     margin-bottom:14px;
#     padding:18px 20px;
#     border-radius:14px;
#     background:rgba(255,255,255,.90);
#     border-left:5px solid #F87171;
#     box-shadow:0 4px 15px rgba(220,38,38,.07);
# ">
#     <div style="
#         width:150px;
#         min-width:150px;
#         font-size:18px;
#         font-weight:800;
#         color:#DC2626;
#     ">chol</div>
#     <div style="
#         width:1px;
#         height:40px;
#         background:#F87171;
#         margin-right:20px;
#     "></div>
#     <div style="
#         font-size:15px;
#         line-height:1.7;
#         color:#374151;
#     ">
#         Serum cholesterol level measured in mg/dl.
#     </div>
# </div>
#
# <!-- fbs -->
#
# <div style="
#     display:flex;
#     align-items:center;
#     margin-bottom:14px;
#     padding:18px 20px;
#     border-radius:14px;
#     background:rgba(255,255,255,.90);
#     border-left:5px solid #F87171;
#     box-shadow:0 4px 15px rgba(220,38,38,.07);
# ">
#     <div style="
#         width:150px;
#         min-width:150px;
#         font-size:18px;
#         font-weight:800;
#         color:#DC2626;
#     ">fbs</div>
#     <div style="
#         width:1px;
#         height:40px;
#         background:#F87171;
#         margin-right:20px;
#     "></div>
#     <div style="
#         font-size:15px;
#         line-height:1.7;
#         color:#374151;
#     ">
#         Fasting blood sugar level categorized as above 120 mg/dl
#         (1 = true, 0 = false).
#     </div>
# </div>
#
# <!-- restecg -->
#
# <div style="
#     display:flex;
#     align-items:center;
#     margin-bottom:14px;
#     padding:18px 20px;
#     border-radius:14px;
#     background:rgba(255,255,255,.90);
#     border-left:5px solid #F87171;
#     box-shadow:0 4px 15px rgba(220,38,38,.07);
# ">
#     <div style="
#         width:150px;
#         min-width:150px;
#         font-size:18px;
#         font-weight:800;
#         color:#DC2626;
#     ">restecg</div>
#     <div style="
#         width:1px;
#         height:40px;
#         background:#F87171;
#         margin-right:20px;
#     "></div>
#     <div style="
#         font-size:15px;
#         line-height:1.7;
#         color:#374151;
#     ">
#         Resting electrocardiographic results:
#         0 = Normal, 1 = ST-T wave abnormality,
#         2 = Probable or definite left ventricular hypertrophy.
#     </div>
# </div>
#
# <!-- thalach -->
#
# <div style="
#     display:flex;
#     align-items:center;
#     margin-bottom:14px;
#     padding:18px 20px;
#     border-radius:14px;
#     background:rgba(255,255,255,.90);
#     border-left:5px solid #F87171;
#     box-shadow:0 4px 15px rgba(220,38,38,.07);
# ">
#     <div style="
#         width:150px;
#         min-width:150px;
#         font-size:18px;
#         font-weight:800;
#         color:#DC2626;
#     ">thalach</div>
#     <div style="
#         width:1px;
#         height:40px;
#         background:#F87171;
#         margin-right:20px;
#     "></div>
#     <div style="
#         font-size:15px;
#         line-height:1.7;
#         color:#374151;
#     ">
#         Maximum heart rate achieved during a stress test.
#     </div>
# </div>
#
# <!-- exang -->
#
# <div style="
#     display:flex;
#     align-items:center;
#     margin-bottom:14px;
#     padding:18px 20px;
#     border-radius:14px;
#     background:rgba(255,255,255,.90);
#     border-left:5px solid #F87171;
#     box-shadow:0 4px 15px rgba(220,38,38,.07);
# ">
#     <div style="
#         width:150px;
#         min-width:150px;
#         font-size:18px;
#         font-weight:800;
#         color:#DC2626;
#     ">exang</div>
#     <div style="
#         width:1px;
#         height:40px;
#         background:#F87171;
#         margin-right:20px;
#     "></div>
#     <div style="
#         font-size:15px;
#         line-height:1.7;
#         color:#374151;
#     ">
#         Exercise-induced angina (1 = yes, 0 = no).
#     </div>
# </div>
#
# <!-- oldpeak -->
#
# <div style="
#     display:flex;
#     align-items:center;
#     margin-bottom:14px;
#     padding:18px 20px;
#     border-radius:14px;
#     background:rgba(255,255,255,.90);
#     border-left:5px solid #F87171;
#     box-shadow:0 4px 15px rgba(220,38,38,.07);
# ">
#     <div style="
#         width:150px;
#         min-width:150px;
#         font-size:18px;
#         font-weight:800;
#         color:#DC2626;
#     ">oldpeak</div>
#     <div style="
#         width:1px;
#         height:40px;
#         background:#F87171;
#         margin-right:20px;
#     "></div>
#     <div style="
#         font-size:15px;
#         line-height:1.7;
#         color:#374151;
#     ">
#         ST depression induced by exercise relative to rest.
#     </div>
# </div>
#
# <!-- slope -->
#
# <div style="
#     display:flex;
#     align-items:center;
#     margin-bottom:14px;
#     padding:18px 20px;
#     border-radius:14px;
#     background:rgba(255,255,255,.90);
#     border-left:5px solid #F87171;
#     box-shadow:0 4px 15px rgba(220,38,38,.07);
# ">
#     <div style="
#         width:150px;
#         min-width:150px;
#         font-size:18px;
#         font-weight:800;
#         color:#DC2626;
#     ">slope</div>
#     <div style="
#         width:1px;
#         height:40px;
#         background:#F87171;
#         margin-right:20px;
#     "></div>
#     <div style="
#         font-size:15px;
#         line-height:1.7;
#         color:#374151;
#     ">
#         Slope of the peak exercise ST segment:
#         0 = Upsloping, 1 = Flat, 2 = Downsloping.
#     </div>
# </div>
#
# <!-- ca -->
#
# <div style="
#     display:flex;
#     align-items:center;
#     margin-bottom:14px;
#     padding:18px 20px;
#     border-radius:14px;
#     background:rgba(255,255,255,.90);
#     border-left:5px solid #F87171;
#     box-shadow:0 4px 15px rgba(220,38,38,.07);
# ">
#     <div style="
#         width:150px;
#         min-width:150px;
#         font-size:18px;
#         font-weight:800;
#         color:#DC2626;
#     ">ca</div>
#     <div style="
#         width:1px;
#         height:40px;
#         background:#F87171;
#         margin-right:20px;
#     "></div>
#     <div style="
#         font-size:15px;
#         line-height:1.7;
#         color:#374151;
#     ">
#         Number of major vessels (0–4) colored by fluoroscopy.
#     </div>
# </div>
#
# <!-- thal -->
#
# <div style="
#     display:flex;
#     align-items:center;
#     margin-bottom:14px;
#     padding:18px 20px;
#     border-radius:14px;
#     background:rgba(255,255,255,.90);
#     border-left:5px solid #F87171;
#     box-shadow:0 4px 15px rgba(220,38,38,.07);
# ">
#     <div style="
#         width:150px;
#         min-width:150px;
#         font-size:18px;
#         font-weight:800;
#         color:#DC2626;
#     ">thal</div>
#     <div style="
#         width:1px;
#         height:40px;
#         background:#F87171;
#         margin-right:20px;
#     "></div>
#     <div style="
#         font-size:15px;
#         line-height:1.7;
#         color:#374151;
#     ">
#         Thalium stress test result:
#         0 = Normal, 1 = Fixed defect,
#         2 = Reversible defect, 3 = Not described.
#     </div>
# </div>
#
# <!-- target -->
#
# <div style="
#     display:flex;
#     align-items:center;
#     margin-bottom:0;
#     padding:18px 20px;
#     border-radius:14px;
#     background:#FCA5A5;
#     border-left:5px solid #B91C1C;
#     box-shadow:0 5px 18px rgba(185,28,28,.10);
# ">
#     <div style="
#         width:150px;
#         min-width:150px;
#         font-size:18px;
#         font-weight:800;
#         color:#991B1B;
#     ">target</div>
#     <div style="
#         width:1px;
#         height:40px;
#         background:#DC2626;
#         margin-right:20px;
#     "></div>
#     <div style="
#         font-size:15px;
#         line-height:1.7;
#         color:#374151;
#     ">
#         Heart disease status (0 = no disease, 1 = presence of disease).
#     </div>
# </div>
#
# </div>

# %% [markdown]
# <div style="
#     margin:25px 0;
#     padding:25px 30px;
#     border-radius:18px;
#     background:linear-gradient(135deg,#450A0A,#B91C1C);
#     box-shadow:0 10px 30px rgba(220,38,38,.25);
#     border-left:6px solid #F87171;
# ">
#
# <h2 style="
#     margin:0;
#     color:white;
#     font-family:Verdana,sans-serif;
#     font-size:28px;
#     letter-spacing:1px;
# ">
#     step_1: importing library
# </h2>
#
# </div>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno
import chardet
import csv

# %% [markdown]
# <div style="
#     margin:25px 0;
#     padding:25px 30px;
#     border-radius:18px;
#     background:linear-gradient(135deg,#450A0A,#B91C1C);
#     box-shadow:0 10px 30px rgba(220,38,38,.25);
#     border-left:6px solid #F87171;
# ">
#
# <h2 style="
#     margin:0;
#     color:white;
#     font-family:Verdana,sans-serif;
#     font-size:28px;
#     letter-spacing:1px;
# ">
#     step_2: checking encoding and delimiter dataset
# </h2>
#
# </div>

# %%
# chardet library: standard data code recognition

with open('heart.csv', 'rb') as encoding_file:
    check_encoding = chardet.detect(encoding_file.read())

print(f'data standard code is: ({check_encoding['encoding']})')
# Out:
# data standard code is: (ascii)

# %%
# csv library: Detecting data values being separated

with open('heart.csv', 'r') as delimiter_file:
    check_delimiter = csv.Sniffer().sniff(delimiter_file.read())

print(f'delimiter data is: ({check_delimiter.delimiter})')
# Out:
# delimiter data is: (,)

# %% [markdown]
# <div style="
#     margin:25px 0;
#     padding:25px 30px;
#     border-radius:18px;
#     background:linear-gradient(135deg,#450A0A,#B91C1C);
#     box-shadow:0 10px 30px rgba(220,38,38,.25);
#     border-left:6px solid #F87171;
# ">
#
# <h2 style="
#     margin:0;
#     color:white;
#     font-family:Verdana,sans-serif;
#     font-size:28px;
#     letter-spacing:1px;
# ">
#     step_3: Loading dataset
# </h2>
#
# </div>

# %%
# importing data heart
data = pd.read_csv('heart.csv')

# Converting a dataset to a dataframe
df = pd.DataFrame(data)

# %%
df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %% [markdown]
# <div style="
#     margin:25px 0;
#     padding:25px 30px;
#     border-radius:18px;
#     background:linear-gradient(135deg,#450A0A,#B91C1C);
#     box-shadow:0 10px 30px rgba(220,38,38,.25);
#     border-left:6px solid #F87171;
# ">
#
# <h2 style="
#     margin:0;
#     color:white;
#     font-family:Verdana,sans-serif;
#     font-size:28px;
#     letter-spacing:1px;
# ">
#     step_4: Preprocessing
# </h2>
#
# </div>

# %%
rows, columns = df.shape

# show rows and columns
print(f'number of data rows: {rows}')
print('=' * 30)
print(f'number of data columns: {columns}')
# Out:
# number of data rows: 303
# ...
# number of data columns: 14

# %%
df.info() # general data information
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  target    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
df.describe(include='all') # Data interpretation
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %% [markdown]
# <div style="
#     margin:25px 0;
#     padding:25px 30px;
#     border-radius:18px;
#     background:linear-gradient(135deg,#450A0A,#B91C1C);
#     box-shadow:0 10px 30px rgba(220,38,38,.25);
#     border-left:6px solid #F87171;
# ">
#
# <h2 style="
#     margin:0;
#     color:white;
#     font-family:Verdana,sans-serif;
#     font-size:28px;
#     letter-spacing:1px;
# ">
#     step_5: checking and handling missing value
# </h2>
#
# </div>

# %%
df.isna().sum() # check missing value in columns
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
msno.bar(df) # Missing Value Check with Bar Plot

plt.show()

# %%
# show percentage missing value(%)

percentage = (df.isna().sum() / len(df)) * 100

per_dict = pd.DataFrame({
    'columns' : df.columns,
    'percentage_missing_value(%)' : percentage
})

result = pd.DataFrame(per_dict)

# show percentage
result
# Out:
#            columns  percentage_missing_value(%)
# age            age                          0.0
# sex            sex                          0.0
# cp              cp                          0.0
# trestbps  trestbps                          0.0
# chol          chol                          0.0
# fbs            fbs                          0.0
# restecg    restecg                          0.0
# thalach    thalach                          0.0
# exang        exang                          0.0
# oldpeak    oldpeak                          0.0
# slope        slope                          0.0
# ca              ca                          0.0
# thal          thal                          0.0
# target      target                          0.0

# %% [markdown]
# <div style="
#     margin:25px 0;
#     padding:25px 30px;
#     border-radius:18px;
#     background:linear-gradient(135deg,#450A0A,#B91C1C);
#     box-shadow:0 10px 30px rgba(220,38,38,.25);
#     border-left:6px solid #F87171;
# ">
#
# <h2 style="
#     margin:0;
#     color:white;
#     font-family:Verdana,sans-serif;
#     font-size:28px;
#     letter-spacing:1px;
# ">
#     step_6: checking and handling Suspicious values
# </h2>
#
# </div>

# %%
# show unique value
for item in df.columns:
    print(f'column: {item}\n')
    print(df[item].unique())
    print('==' * 50)
# Out:
# column: age
#
# [63 37 41 56 57 44 52 54 48 49 64 58 50 66 43 69 59 42 61 40 71 51 65 53
#  46 45 39 47 62 34 35 29 55 60 67 68 74 76 70 38 77]
# ...
# column: sex
#
# [1 0]
# ...
# column: cp
#
# [3 2 1 0]
# ...
# column: trestbps
#
# [145 130 120 140 172 150 110 135 160 105 125 142 155 104 138 128 108 134
#  122 115 118 100 124  94 112 102 152 101 132 148 178 129 180 136 126 106
#  156 170 146 117 200 165 174 192 144 123 154 114 164]
# ...
# column: chol
#
# [233 250 204 236 354 192 294 263 199 168 239 275 266 211 283 219 340 226
#  247 234 243 302 212 175 417 197 198 177 273 213 304 232 269 360 308 245
#  208 264 321 325 235 257 216 256 231 141 252 201 222 260 182 303 265 309
#  186 203 183 220 209 258 227 261 221 205 240 318 298 564 277 214 248 255
#  207 223 288 160 394 315 246 244 270 195 196 254 126 313 262 215 193 271
#  268 267 210 295 306 178 242 180 228 149 278 253 342 157 286 229 284 224
#  206 167 230 335 276 353 225 330 290 172 305 188 282 185 326 274 164 307
# ...

# %%
print(f'maximum age is: {df['age'].max()}') # maximum age
print('==' * 30)
print(f'minimum age is: {df['age'].min()}') # minimum age
# Out:
# maximum age is: 77
# ...
# minimum age is: 29

# %%
# show unique value and counts unique value
for item in df.columns:
    print(f'column {item}\n')
    print(df[item].value_counts())
    print('==' * 50)
# Out:
# column age
#
# age
# 58    19
# 57    17
# 54    16
# 59    14
# 52    13
# 51    12
# 56    11
# 44    11
# 62    11
# 60    11
# 41    10
# 64    10
# 63     9
# 67     9
# 43     8
# 42     8
# 61     8
# 65     8
# 53     8
# 45     8
# 55     8
# 48     7
# 50     7
# 66     7
# 46     7
# 49     5
# 47     5
# 39     4
# 35     4
# 68     4
# 70     4
# 69     3
# 40     3
# 71     3
# 38     3
# 37     2
# 34     2
# 29     1
# 74     1
# 76     1
# 77     1
# Name: count, dtype: int64
# ...
# column sex
#
# sex
# 1    207
# 0     96
# Name: count, dtype: int64
# ...
# column cp
#
# cp
# 0    143
# 2     87
# 1     50
# 3     23
# Name: count, dtype: int64
# ...
# column trestbps
#
# trestbps
# 120    37
# 130    36
# 140    32
# 110    19
# 150    17
# 138    13
# 128    12
# 160    11
# 125    11
# 112     9
# 132     8
# 118     7
# 135     6
# 108     6
# 124     6
# 145     5
# 134     5
# 152     5
# 122     4
# 100     4
# 170     4
# 105     3
# 142     3
# 115     3
# 180     3
# ...

# %%
df.nunique() # count unique value
# Out:
# age          41
# sex           2
# cp            4
# trestbps     49
# chol        152
# fbs           2
# restecg       3
# thalach      91
# exang         2
# oldpeak      40
# slope         3
# ca            5
# thal          4
# target        2
# dtype: int64

# %% [markdown]
# <div style="
#     margin:25px 0;
#     padding:25px 30px;
#     border-radius:18px;
#     background:linear-gradient(135deg,#450A0A,#B91C1C);
#     box-shadow:0 10px 30px rgba(220,38,38,.25);
#     border-left:6px solid #F87171;
# ">
#
# <h2 style="
#     margin:0;
#     color:white;
#     font-family:Verdana,sans-serif;
#     font-size:28px;
#     letter-spacing:1px;
# ">
#     step_7:  Data visualization and EDA
# </h2>
#
# </div>

# %%
df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %% [markdown]
# ## show gender and gender number

# %%
df['sex'].value_counts() # Display unique value and number of unique value
# Out:
# sex
# 1    207
# 0     96
# Name: count, dtype: int64

# %%
gender = ['female', 'male']
count = df['sex'].value_counts()
bar_label = ['female:', 'male:']
bar_color = ['fuchsia', 'Aqua']

# subplots
fig, ax = plt.subplots(figsize=(10, 5), dpi=200)

# bar plot
bar = ax.bar(gender, count, label=bar_label, color=bar_color)

# axis barplot(title, label, legend,....)
ax.set_title('show gender & gender count', fontsize=20, weight='bold', color='gray')
ax.set_xlabel('show gender', fontsize=13, weight='bold', color='gray')
ax.set_ylabel('show gender count', fontsize=15, weight='bold', color='gray')
ax.legend(title='show gender', fontsize=13 ,title_fontsize=15, loc='best',
markerfirst=False, shadow=True, fancybox=True, framealpha=0.9, edgecolor='black')
ax.set_ylim(0, 250)
ax.bar_label(bar, label_type='center')
ax.tick_params(axis='both', labelsize=12)

plt.tight_layout() # Suitable space for axes


plt.show() # show plot

# %%
label_gender = ['female', 'male'] # gender
values = df['sex'].value_counts() # count gender 

# subplots
fig, ax = plt.subplots(figsize=(10, 5), dpi=150)

# pie plot
ax.pie(values, labels=label_gender, autopct=f'%1.1f%%', colors=['fuchsia', 'Aqua'], explode=(0.05, 0.05),
      wedgeprops={'edgecolor' : 'black', 'linewidth' : 1.5})

# axis
ax.set_title('show gender & gender count', fontsize=15, weight='bold', color='dimgray')
ax.legend(title='show gender', title_fontsize=12, markerfirst=False, shadow=True, fancybox=True, framealpha=0.8,
          loc='upper right', edgecolor='black')


plt.tight_layout()



# show plot
plt.show()

# %% [markdown]
# ## Showing people who have various types of chest pain

# %%
# Creating a dataframe to put indexes together
gender_counts_by_cp = df.groupby(['cp', 'sex']).size().unstack(fill_value=0)

print(gender_counts_by_cp)
# Out:
# sex   0    1
# cp
# 0    39  104
# 1    18   32
# 2    35   52
# 3     4   19

# %%
labels = ('Typical angina', 'Atypical angina', 'Non-anginal pain', 'Asymptomatic') 
gender_dict = {
    'female:' : np.array([104, 32, 52, 19]),
    'male:' : np.array([39, 18, 35, 4])
}

# bar colors
colors={
    'female:' : '#ED6AFF',
    'male:' : '#51A2FF'
}

x = np.arange(len(labels)) # the label location
width = 0.25
multiplier = 0

# subplot
fig, ax = plt.subplots(figsize=(10, 5), dpi=200)

# create barplot loop
for gender, count in gender_dict.items():
    target = width * multiplier
    barplot = ax.bar(x + target, count, width, label=gender, color=colors[gender])
    ax.bar_label(barplot, padding=3)
    multiplier += 1

# add labels, tile and .... axis's
ax.set_title('show People with chest pain', fontsize=20, color='black', weight='bold')
ax.set_xlabel('Type of chest pain', fontsize=12, color='dimgray', weight='bold')
ax.set_ylabel('Number of chest pains in men & women', fontsize=12, color='dimgray', weight='bold')
ax.set_xticks(x + width, labels)
ax.set_ylim(0, 120)
ax.tick_params(axis='both', labelsize=11)
ax.legend(fontsize=13,
         markerfirst=False, shadow=True, fancybox=True, framealpha=0.9, 
         edgecolor='black', loc='upper center', ncol=2)


plt.tight_layout()

plt.show()

# %% [markdown]
# # show blood pressure of people by age

# %%
plt.figure(figsize=(10, 5), dpi=200)

# scatter plot
plt.scatter(df['age'], df['trestbps'], s=170, alpha=0.4, marker='o', color='#615FFF', label=['show blood pressure'])

# Draw a horizontal line
plt.axhline(y=120, color='green', linestyle='--', label='normal')
plt.axhline(y=140, color='yellow', linestyle='--', label='high')
plt.axhline(y=180, color='red', linestyle='--', label='very high')

# text in scatter plot
plt.text(28, 108, 'normal\n(x < 120)')
plt.text(28, 148, 'high\n(140<x<180)')
plt.text(28, 188, 'very high\n(x > 180)')

# add axis's
plt.title('show Blood pressure of people by age', fontsize=20, color='black', weight='bold')
plt.xlabel('show age', fontsize=13, color='gray', weight='bold')
plt.ylabel('Display of resting systolic blood pressure', fontsize=13, color='gray', weight='bold')
plt.grid(True, linestyle='--', linewidth=0.6)

plt.tight_layout()



plt.show()

# %% [markdown]
# ## show blood cholesterol of people by age

# %%
plt.figure(figsize=(10, 5), dpi=200)

# scatter plot
plt.scatter(df['age'], df['chol'], s=150, alpha=0.4, marker='o', color='#2C92B8')

# Draw a horizontal line
plt.axhline(y=200, color='green', linestyle='--', linewidth=1)
plt.axhline(y=240, color='red', linestyle='--', linewidth=1)

# text in scatter plot
plt.text(28, 140, 'normal\n(x < 200)', fontsize=9)
plt.text(28, 210, 'high\n(200 < x < 239', fontsize=8)
plt.text(28, 250, 'very high\n(x > 240)', fontsize=9)

# axis
plt.title('Blood cholesterol display based on age', fontsize=20, weight='bold')
plt.xlabel('show age', fontsize=15)
plt.ylabel('show blood cholesterol', fontsize=15)
plt.grid(True, linestyle='--', linewidth=0.5)


# annotate
plt.annotate('this sample\n(outlier)', xytext=(55, 450), xy=(66, 557),
            arrowprops=dict(color='green', arrowstyle='->'),
            fontsize=13)


plt.tight_layout()



plt.show()

# %% [markdown]
# ## Display of maximum heart rate achieved based on age

# %%
plt.figure(figsize=(10, 5), dpi=200)

# scatter plot
plt.scatter(df['age'], df['thalach'], s=150, alpha=0.5 ,marker='o', color='#E1712B')

# axis
plt.title('Display of maximum heart rate achieved based on age', fontsize=15, weight='bold', color='dimgrey')
plt.xlabel('show age', fontsize=15, weight='bold', color='dimgrey')
plt.ylabel('Display of maximum achieved heart rate', fontsize=13, color='dimgrey', weight='bold')
plt.grid(True, linestyle='--', linewidth=0.5)


plt.tight_layout() # indent in plot


plt.show()

# %% [markdown]
# ## ST depression induced by exercise relative to rest

# %%
plt.figure(figsize=(10, 5), dpi=200)

# scatter plot
plt.scatter(df['age'], df['oldpeak'], s=150, alpha=0.5, marker='o', color='#024A70')


# Draw a horizontal line
plt.axhline(y=0.2, linestyle='--', linewidth=1, color='green')
plt.axhline(y=1, linestyle='--', linewidth=1, color='yellow')
plt.axhline(y=2, linestyle='--', linewidth=1, color='red')


# text in plot
plt.text(28, 0.4 ,'good\n(x < 1)', fontsize=9) 
plt.text(28, 1.3 ,'danger\n(1 < x < 2)', fontsize=9)
plt.text(28, 2.3 ,'Critical situation\n(x > 2)', fontsize=9)

# axis
plt.title('Exercise-induced ST depression compared to rest in individuals by age', fontsize=12, weight='bold', color='black')
plt.xlabel('show age people', fontsize=15, weight='bold', color='gray')
plt.ylabel('ST depression induced by exercise relative to rest', fontsize=10, weight='bold', color='gray')
plt.grid(True, linestyle='--', linewidth=0.5)

plt.tight_layout()


plt.show()

# %% [markdown]
# # Fasting blood sugar

# %%
sort_index = df.groupby(['fbs', 'sex']).size().unstack(fill_value=0)

print(sort_index)
# Out:
# sex   0    1
# fbs
# 0    84  174
# 1    12   33

# %%
fbs = ('Fasting blood sugar(Yes)\n(x > 120)', 'Fasting blood sugar(No)\n(x < 120)')
size = {
    'female' : np.array([33, 174]),
    'male' : np.array([12, 84])
}

# bar color
bar_color={
    'female' : '#FF637E',
    'male' : '#2B7FFF'
}


width = 0.4
bottom = np.zeros(2)

# subplots
fig, ax = plt.subplots(figsize=(10, 5), dpi=200)

# loop bar plot
for gender, values in size.items():
    bar_fbs = ax.bar(fbs, values, width, bottom=bottom, color=bar_color[gender])
    bottom += values

    ax.bar_label(bar_fbs, label_type='center')

# axis
ax.set_title('Displaying fasting blood sugar based on gender', fontsize=17, weight='bold', color='dimgray')
ax.set_xlabel("Showing people with fasting blood sugar above 120:\n(those who have and those who don't)", fontsize=13, weight='bold', color='dimgrey')
ax.set_ylabel('Blood sugar display', fontsize=17, weight='bold', color='dimgrey')
ax.legend(title='show gender' ,labels=['female', 'male'], title_fontsize=12, markerfirst=False, shadow=True, fancybox=True, framealpha=0.8,
         edgecolor='black', ncol=2, loc='upper left')


plt.tight_layout()

plt.show()

# %% [markdown]
# # show people with and without heart disease

# %%
groupby_sorting = df.groupby(['target', 'sex']).size().unstack(fill_value=0)

print(groupby_sorting)
# Out:
# sex      0    1
# target
# 0       24  114
# 1       72   93

# %%
disease = ('no disease', 'presence of disease')
count_disease = {
    'female' : (114, 93),
    'male' : (24, 72)
}

# bar colors
bar_color = {
    'female' : '#E12AFB',
    'male' : '#2B7FFF'
}

x = np.arange(len(disease)) # the label locations
width = 0.25
multiplier = 0

# subplots
fig, ax = plt.subplots(figsize=(10, 5), dpi=200)

# loop barplot
for gender, values in count_disease.items():
    solution = width * multiplier
    bar = ax.bar(x + solution, values, width, label=gender, color=bar_color[gender])
    ax.bar_label(bar, padding=3)
    multiplier += 1

# axis
ax.set_title('show people With and without heart disease', fontsize=20, weight='bold', color='dimgray')
ax.set_xlabel('With and without heart disease', fontsize=15, weight='bold', color='dimgray')
ax.set_ylabel('count people With and without heart disease', fontsize=12, weight='bold', color='dimgray')
ax.set_xticks(x + width, disease)
ax.set_ylim(0, 150)
ax.legend(title='show gender', title_fontsize=12, markerfirst=False, shadow=True, fancybox=True, framealpha=0.8,
         edgecolor='black', loc='upper center', ncol=2)
ax.tick_params(axis='both', labelsize=12)

plt.tight_layout()

plt.show()

# %% [markdown]
# # Showing people with and without exercise-induced angina

# %%
# crate dataframe
group_index = df.groupby(['exang', 'sex']).size().unstack(fill_value=0)

print(group_index)
# Out:
# sex     0    1
# exang
# 0      74  130
# 1      22   77

# %%
labels = ('Non-exercise-induced angina', 'Suffering from exercise-induced angina')
size = {
    'female' : np.array([130, 77]),
    'male' : np.array([74, 22])
}

# bar color
colors={
    'female' : '#DA9BE4',
    'male' : '#00FFFF'
}

width = 0.6
bottom = np.zeros(2)

# subplots
fig, ax = plt.subplots(figsize=(10, 5), dpi=200)

# loop barplot
for gender, count in size.items():
    bar = ax.bar(labels, count, width, label=gender, color=colors[gender], bottom=bottom)
    ax.bar_label(bar, label_type='center')
    bottom += count
    
# axis
ax.set_title('Showing people with and without exercise-induced angina', fontsize=17, weight='bold', color='grey')
ax.set_xlabel('Patients with exercise-induced and\nnon-exercise-induced angina', fontsize=13, weight='bold', color='grey')
ax.set_ylabel('Number of people with and without\nexercise-induced angina', fontsize=13, weight='bold', color='grey')
ax.legend(title='show gender', title_fontsize=12, markerfirst=False, shadow=True, fancybox=True, framealpha=0.8,
          edgecolor='black', loc='upper right', ncol=2)
ax.set_ylim(0, 250)
ax.bar_label(bar, padding=3)
ax.tick_params(axis='both', labelsize=10)

plt.tight_layout()

plt.show()

# %%
value_index = df.groupby(['thal', 'sex']).size().unstack(fill_value=0)

print(value_index)
# Out:
# sex    0    1
# thal
# 0      1    1
# 1      1   17
# 2     79   87
# 3     15  102

# %%
label_column_thal = ('Normal', 'Fixed defect', 'Reversible defect', 'Not described')
count_column_thal = {
    'female' : (1, 17, 87, 102),
    'male' : (1, 1, 79, 15)
}

# bar_colors
colors = {
    'female' : '#F54927',
    'male' : '#8207DB'
}


x = np.arange(len(label_column_thal))
width = 0.2
multiplier = 0

# subplots
fig, ax = plt.subplots(figsize=(10, 5), dpi=200)


# loop barplot
for gender, counts in count_column_thal.items():
    solution = width * multiplier
    barplot = ax.bar(x + solution, counts, width, label=gender, color=colors[gender])
    ax.bar_label(barplot, padding=3)
    multiplier += 1

# axis
ax.set_title('Demonstration of blood flow in the heart in humans', fontsize=20, weight='bold', color='gray')
ax.set_xlabel('Types of heart blood flow tests', fontsize=15, weight='bold', color='gray')
ax.set_ylabel('Number of people tested', fontsize=15, weight='bold', color='gray')
ax.set_xticks(x + width, label_column_thal)
ax.set_ylim(0, 150)
ax.legend(title='show gender', title_fontsize=12, markerfirst=False, shadow=True, fancybox=True, framealpha=0.8,
         edgecolor='black', loc='upper left', ncol=2)

plt.tight_layout()


plt.show()

# %% [markdown]
# # showing people's heart condition

# %%
sort_df = df.groupby(['restecg', 'sex']).size().unstack(fill_value=0)

print(sort_df)
# Out:
# sex       0    1
# restecg
# 0        44  103
# 1        49  103
# 2         3    1

# %%
label_restecg = ('Normal', 'Having ST-T wave abnormality', 'Showing probable or\ndefinite left ventricular hypertrophy')
count_restecg = {
    'female' : (103, 103, 1),
    'male' : (44, 49, 3)
}

# bar_colors
restecg_colors = {
    'female' : '#00BDF5',
    'male' : '#EBEB7A'
}


x = np.arange(len(label_restecg))
width = 0.2
multiplier = 0

# subplots
fig, ax = plt.subplots(figsize=(10, 5), dpi=200)


# loop barplot
for gender, counts_value in count_restecg.items():
    solution = width * multiplier
    barplot = ax.bar(x + solution, counts_value, width, label=gender, color=restecg_colors[gender])
    ax.bar_label(barplot, padding=3)
    multiplier += 1

# axis
ax.set_title("Showing people's heart condition", fontsize=20, weight='bold', color='gray')
ax.set_xlabel('Heart condition display', fontsize=15, weight='bold', color='gray')
ax.set_ylabel('Status number', fontsize=15, weight='bold', color='gray')
ax.set_xticks(x + width, label_restecg)
ax.set_ylim(0, 150)
ax.legend(title='show gender', title_fontsize=12, markerfirst=False, shadow=True, fancybox=True, framealpha=0.8,
         edgecolor='black', loc='upper right', ncol=2)

plt.tight_layout()


plt.show()

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:100px;
#            background:linear-gradient(135deg,#991B1B,#DC2626);
#            font-size:120%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
#
# <p style="padding:50px;
#           color:white;">
# As you have seen throughout this notebook, the heart plays a very important and fundamental role in our lives. We should take good care of our hearts, and be grateful that having a heart allows us to love, feel alive, and experience the beauty of life...
# If you notice any part of the code, incomplete output, or any problem with my work, or if you think there is something I should have added to make my notebook better, I would really appreciate it if you let me know in the comments.
# Thank you so much for staying with me until the end of this notebook. I would be very happy if you could support me by giving it a Vote and leaving a comment. Your support gives me energy and helps make all the effort worthwhile.
#
# </p>
# </div>

# %% [markdown]
# <div style="
#     margin:40px 0;
#     padding:55px 30px;
#     border-radius:30px;
#     background:linear-gradient(145deg,#fff1f2,#ffe4e6);
#     box-shadow:0 12px 35px rgba(190,24,93,.15);
#     text-align:center;
#     border:1px solid #fecdd3;
# ">
#
# <div style="
#     font-size:42px;
#     margin-bottom:20px;
# ">
#     🫀
# </div>
#
# <p style="
#     margin:0;
#     color:#881337;
#     font-family:Georgia,serif;
#     font-size:30px;
#     font-style:italic;
#     letter-spacing:1px;
# ">
#     I leave you in the care of the Almighty God.
# </p>
#
# <p style="
#     margin:18px 0 0 0;
#     color:#be123c;
#     font-family:Verdana,sans-serif;
#     font-size:14px;
#     letter-spacing:3px;
# ">
#     UNTIL NEXT TIME
# </p>
#
# <div style="
#     margin:25px auto 0 auto;
#     color:#e11d48;
#     font-size:18px;
# ">
#     ─────── ♥ ───────
# </div>
#
# </div>
